# %%
list_1 = [1,2,3,4,"depi","learning",True,[1,2,3,"true",["ML","DL","GenAI"]]]

# %%
print(type(list_1))
# Out:
# <class 'list'>

# %%
list_1[5]
list_1[7][4][1] = "Deep Learning"
list_1
# Out:
# [1,
#  2,
#  3,
#  4,
#  'depi',
#  'learning',
#  True,
#  [1, 2, 3, 'true', ['ML', 'Deep Learning', 'GenAI']]]

# %% [markdown]
# Add item to list
#
# append()
#
# insert()
#
# extend()

# %%
list_2 = ["depi","Learning","Python"]
x= list_2.append("ML")
list_2
# Out:
# ['depi', 'Learning', 'Python', 'ML']

# %%
list_2 = ["depi","Learning","Python"]
x= list_2.append("ML")
print(list_2)
print(x)
# Out:
# ['depi', 'Learning', 'Python', 'ML']
# None

# %%
list_2 = ["depi","Learning","Python"]
list_2.insert(1,9)
list_2
# Out:
# ['depi', 9, 'Learning', 'Python']

# %%
list_2 = ["depi","Learning","Python"]
list_2.extend("Machine")
list_2
# Out:
# ['depi', 'Learning', 'Python', 'M', 'a', 'c', 'h', 'i', 'n', 'e']

# %%
list_2 = ["depi","Learning","Python"]
new_list = list_2 + ["Machine"]
print(list_2)
print(new_list)
# Out:
# ['depi', 'Learning', 'Python']
# ['depi', 'Learning', 'Python', 'Machine']

# %% [markdown]
# delet item from list
#
# remove()
#
# pop()
#
# del()

# %%
list_2 = ["depi","Learning","Python"]
list_2.remove("depi")
list_2
# Out:
# ['Learning', 'Python']

# %%
list_2 = ["depi","Learning","Python"]
x = list_2.pop()
print(list_2)
print(x)
# Out:
# ['depi', 'Learning']
# Python

# %%
list_2 = ["depi","Learning","Python"]
del list_2[1]
list_2
# Out:
# ['depi', 'Python']

# %%
list_1 = ["Depi","nti","iti"]
new_list = []
task_1 = list_1.pop()
new_list.append(task_1)
print(list_1)
print(task_1)
# Out:
# ['Depi', 'nti']
# iti
