# %%
x = 10
print(x)
# Out:
# 10

# %%
name= "Mohamed"
age= 21
date= "1/8/2026"
course= "AI&ML"
output= f"My name is {name}, My age is {age} and the course that i learned is {course} in data is {date}"
print(output)
# Out:
# My name is Mohamed, My age is 21 and the course that i learned is AI&ML in data is 1/8/2026

# %%
name = "Moahmed"
name[0],name[5],name[3]
# Out:
# ('M', 'e', 'h')

# %%
sent = "Depi for Machien Learning"
print(sent[17:25:1])
# Out:
# Learning

# %%
sent = "depi Machien Learning for everyone"
capital =sent.upper()
capital
# Out:
# 'DEPI MACHIEN LEARNING FOR EVERYONE'

# %%
lower_case = sent.lower()
lower_case
# Out:
# 'depi machien learning for everyone'

# %%
sent = "Depi for Machien Learning"
print(sent.replace("Machien","deep"))
# Out:
# Depi for deep Learning
