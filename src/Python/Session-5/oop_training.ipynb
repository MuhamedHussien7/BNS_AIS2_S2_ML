# %%
class Member:
    def __init__(self,first_name,middle_name,last_name):
        self.f_name = first_name
        
        self.m_name = middle_name
        
        self.l_name = last_name

# %%
member_one = Member("Mohamed", "Hussein", "Amr")
member_two = Member("Ahmed", "Hussein", "Mohamed")
member_three = Member("Amr", "Mohamed", "Ahmed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 member_one = Member("Mohamed","Hussein","Amr")
#       2 member_two = Member("Ahmed","Hussein","Mohamed")
#       3 member_three = Member("Amr","Mohamed","Ahmed")
#
# TypeError: Member.__init__() takes 2 positional arguments but 4 were given

# %%
print(member_one.name)
print(member_two.name)
print(member_three.name)
# Out:
# Mohamed
# Ahmed
# Amr
